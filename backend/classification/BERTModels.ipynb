# %%
import numpy as np
import json
import glob
import re

# gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# spacy
import spacy
from nltk.corpus import stopwords

# vis
import pyLDAvis
import pyLDAvis.gensim

import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %%
def data_length(file):
    # global jsonLength
    with open(file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    # jsonLength = len(data)
    return len(data)


def load_data(file):
    with open(file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    return data

# %%
# print(data_length('./backend/datasets/combined_data.json'))
length = data_length('C:/Hammad Aslam/BS IT (post ADP)/3rd Semester/Capstone Project/Project/backend/datasets/categories/allFiles/mens_jackets.json')
data_array = []
for i in range(0, length):
    data = load_data(
        'C:/Hammad Aslam/BS IT (post ADP)/3rd Semester/Capstone Project/Project/backend/datasets/categories/allFiles/mens_jackets.json')[i]["product_title"]
    data_array.append(data[0])
    # print(data)

# print(data_array)

# stopwords = stopwords.words('english')
# print (stopwords)

# lemmatization
# data_array

# %%
def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])
    text_out = []
    # a = texts.split()
    # b = [x for x in a if x!='']
    for text in texts:
        new_record = re.sub(' +', ' ', text)
        # print(new_record)
        doc = nlp(new_record)
        # print(doc)
        newText = []
        for token in doc:
            # if token.pos_ in allowed_postags:
            newText.append(token.lemma_)
            # token_list = [token for token in doc]
            filtered_list = [token for token in doc if not token.is_stop]
            lemmas = [
                f"{token.lemma_}"
                for token in filtered_list
            ]
            # string = ' '.join(lemmas)
        final = " ".join(lemmas)
        text_out.append(final)
    return text_out


lemmatizedText = lemmatization(data_array)
# print(lemmatizedText)
# lemmatizedText
# Out:
# ['DuDubaby Mens Flannel Jacket Cotton Jacket Lightweight Jacket Spring Fall Causal Windbreaker Coat Outerwear Long Fur Coat',
#  'heat Jacket Mens Slim Fit Casual Denim Jacket Solid Colour Denim Casual Lapel Long Sleeve',
#  'DuDubaby Men S Autumn Winter Clothing Zipper Pocket Loose Coat Mens Lightweight Jacket',
#  'Men Slim Collar Suit chinese wedding Dress Tang Jacket Suit Casual Button Blazer Traditional Uniform Groom',
#  'Mens Flannel Jacket Mens Fleece Lined Jacket Casual Winter Warm Blouse Thickening Coat Outwear Blouse Jacket',
#  'Xpril Men s 2 tone Vivid Color sporty design zip outdoor jacket',
#  'Hereyeth Men s Winter Jacket Fleece Tactical Military Jacket Fall Waterproof Coat pocket',
#  'Result Mens Core Adult Windcheater Water Repellent Windproof Jacket M Hot Pink',
#  'Motion Men s Softshell Sherpa Jacket',
#  'Independent Trading Co men hood',
#  'Hat Mens Warmth Retaining Waterproof Coat Hood Zipper Pocket',
#  'Cresta Outdoor Men s Camouflage Printed Softshell Jacket',
#  'DuDubaby Men s Fashion Long sleeve Warm Camouflage Printed hood Jacket',
#  'regatta Professional Mens Octagon II Waterproof Softshell Jacket',
#  'DuDubaby Men S Autumn Long sleeve Splicing Sweatshirt Tee Blouse Jacket Coat',
#  'result Mens Ripstop Soft Shell Breathable Jacket',
#  'stormhide Waterproof Pour Rain Jacket Gamehide Loden XL',
#  'Ouray Sportswear Adult Men Hybrid Ii Jacket',
#  'Result Mens Classic Softshell Breathable Jacket',
#  'CIKRILAN Mens Long Sleeve Soft Shell Fleece Coat Sport Travelling Cycling Jacket',
#  'Clementine Men s ultc 8280 soft Shell Jacket Cadet Collar',
#  'CIKRILAN men Softshell Fleece Lined Windproof Outdoor Sports Jacket Coat Outwear',
#  'Xpril Men s Functional weatherproof outdoor windbreaker Jacket',
#  'CIKRILAN Men s hooded Outdoor Soft Shell Fleece Lined Jacket Breathable Coat',
#  'Topway Men s Softshell Windproof Water Resistant Fleece Lined Jacket Sports Coat',
#  'TEAM 365 Men s Leader Soft Shell Jacket Sport Purple XX large',
#  'team 365 Men s Leader Soft Shell Jacket 4XL SPORT MAROON',
#  'Outofgas New Men s HI VIZ Bomber Jacket Waterproof pad Hooded Coat high Visibility Work Jacket',
#  'Result Mens Softshell Bodywarmer Breathable Jacket',
#  'DEFCON 5 Tactical Softshell Jacket Detachable Hood OD Green Black Coyote Brown d5 3430 OD B cb',
#  'Colorado Clothing Men s Summit Anorak Shell Jacket',
#  'regatta Mens Tyler Jacket',
#  'World Famous Sports Waterproof Breathable Camo Parka Blaze Woodland Blaze Camo 2xl',
#  'mountain Warehouse Mens Waterproof Jacket Breathable Rain Jacket',
#  'Cresta Outdoor Men s Triclimate 3 1 Softshell jacket',
#  'World Famous Sports Waterproof Breathable Camo Parka Blaze Woodland Blaze Camo XL',
#  'Uneek UC611 Mens Premium Zip Softshell Jacket',
#  'CIKRILAN Men s 3in1 Windproof Waterproof Fleece Liner Jacket Coat Sports Outwear',
#  'Ash City Core 365 Men s tall Brisk Insulated Jacket 2xt CLASSIC NAVY',
#  'Port Authority Men s Glacier Soft Shell Jacket XXL Atlantic Blue Chrome',
#  'Mountain Warehouse Firth Mens Softshell Jacket Water Resistant',
#  'Izas Men s Karako Jacket',
#  'Devon Jones DG440 Mens Stretch Tech Shell Compass Navy l',
#  'JOBMAN Workwear Men s Deluxe Soft Shell Jacket',
#  'Native Species Men s Thunderhawk Insulated Jacket Vertigo',
#  'north end Layer Fleece Bonded Soft Shell Technical Jacket 88138 Black 703 4xl',
#  'regatta Standout Mens Arcola 3 Layer Waterproof Breathable Softshell Jacket',
#  'Pendleton Outerwear Men s billing',
#  'orage Men s Slogan Jacket',
#  'Rocky Men s Waterfowler Waterproof insulated Jacket',
#  'Ash City Core 365 Men s tall Brisk Insulated Jacket 5XT BLACK',
#  '2 Tone Bomber Jacket',
#  'Mishmi Takin Misti Water Resistent Wind Resistant Bonded Fleece Softshell Men s jacket',
#  'Red Ledge Unisex Adult Fortitech Jacket Soft Shell Jacket',
#  'Mountain Warehouse Zenith Extreme III Mens 3 1 jacket',
#  'Harriton Echo Soft Shell Jacket M780',
#  'ASICS Men s Electro Jacket',
#  'AquaGuard Men s Modern',
#  'man s Layer Fleece Bonded Performance Soft Shell Jacket 4XL BLACK',
#  'craghopper Men s NAT Geo Pro Lite Softshell Jacket',
#  'remember deploy RED Friday Embroidered 1 2 Zip Soft Shell Jacket Red',
#  'craghopper Men s Ikuya Soft Shell Jacket',
#  'Helikon Trooper Soft Shell Jacket Alpha Green',
#  'SANGAMSTEELCRAFT gambeson REMOVABLE SLEEVES WHITE',
#  'Falcon Bay Big Tall Mens Zip Insulated Liner Jacket',
#  'craghopper Men s Kiwi Jacket',
#  'craghopper Men s Hsuki Jacket',
#  'coburn R2801 sl Warm Jacket f Small Calf silver',
#  'helly Hansen Men s Gothenburg Lightweight Fitted Waterproof Coat Jacket Package Hood',
#  'Mizuno Premier Practice',
#  'Heat Holders Mens Winter Warm Waterproof Fleece Insulated Packable Puffer Jacket',
#  'World Famous Sports Waterproof Breathable Camo Parka Blaze Woodland Blaze Camo LARGE',
#  'Harriton Men s Raglan Sleeves Nylon Staff Jacket',
#  'Mishmi Takin Qaras Waterproof Windproof High Loft Fleece Lined Soft Shell Men s Mustard Yellow Jacket Medium',
#  'Mountain Warehouse Gorge Mens Long Waterproof Rain Jacket winter',
#  'Fjällräven Keb pad Hoodie',
#  'Mishmi Takin Virunga 3 Layer Event Waterproof Windproof Hard Shell Ski Climbing Jacket Men s',
#  'Sherpa Adventure Gear Tingri Jacket',
#  'Rocky Men s Vitals hood jacket',
#  'Helikon Gunfighter Soft Shell Jacket Jungle Green',
#  'Red Ledge Men s Reprieve Jacket Soft Shell Jacket',
#  'ICEWEAR Kevin Wool softshell 3 Layer Jacket',
#  'DuDubaby Lightweight Jacket Men tie Dye Jacket Casual Camouflage Sports Sweatshirt Long sleeve Zipper hood Jacket Coat',
#  'Pentagon Men s Hercules Fleece Jacket 2 0 coyote',
#  'ERESMISOL Men s Outdoor Waterproof Softshell Fleece Hooded Military Tactical Jacket',
#  'UltraClub Men s Water Resistant Elastic Drawstring Rip Shell Jacket',
#  '2xu Men s Hyoptik Jacket',
#  'Portwest Men s jacket',
#  'Big Mens Summit Jacket Contrasting panel',
#  'north end Height Men s 3 1 waterproof Insulated Liner Jacket',
#  'Ice Armor Men s Edge Cold Weather Parka',
#  'Walker Hawkes Men s Wax 3 1 Greendale Jacket',
#  'Mountain Warehouse Brisk Extreme Mens Waterproof Jacket',
#  'Pentagon Reiner 2 0 Men s Softshell Jacket Grindle Green',
#  'man s Layer Fleece Bonded Performance Soft Shell Jacket 3XL black',
#  'craghopper Men s Hiro Insulated Soft Shell Jacket',
#  'Port Authority Challenger Jacket J754 Royal Navy',
#  'Port Authority Challenger Jacket J754',
#  'Columbia Men s Thermodynamic Softshell Charcoal Small',
#  'STS Ranchwear Men s Young Gun Softshell Jacket',
#  'Columbia Men s Glacier Glade III Parka',
#  'LONDON FOG Men s Soft Shell Detachable Hood',
#  'Port Authority Challenger Jacket J754 Red Navy',
#  'Columbia Men s Thermarator II Tall Jacket',
#  'Port Authority Team Jacket Bright Navy Light Oxford 3xl',
#  'Port Authority Team Jacket Maroon Light Oxford L',
#  'Port Authority Team Jacket Red Light Oxford XL',
#  'Spiewak Men s Hancock Aviator Jacket',
#  'GORE WEAR Men s r3 Partial GTX jacket',
#  'north end Men s 3 1 tone Parka',
#  'Port Authority Mens Competitor Jacket JP54',
#  'ASICS Men s Lite Jacket',
#  'Jack Wolfskin Moonrise Jacket Men',
#  'Port Authority Challenger Jacket J754',
#  'Port Authority Textured Hooded Soft Shell Jacket J706 Apparel',
#  'MV Sport Liberty Jacket',
#  'NORTH FACE Men s 1994 Retro Mountain Light Futurelight Jacket',
#  'Oakley Men s Sub Temp Recycled Gore tex Jacket',
#  'Port Authority Men s Tone Soft Shell Jacket',
#  'ARIAT Men s Fr Workhorse insulated Jacket',
#  'Port Authority Men s 3 1 Jacket L Navy Navy',
#  'killtec Men Functional Jacket KOW 161 MN',
#  'Salomon fast wing aero men',
#  'Port Authority J318 Men s Polyester Core Colorblock Soft Shell Jacket XX large Black Imperial Blue',
#  'Port Authority Team Jacket JP56',
#  'Quiksilver Men s Tr Stretch 30k Snow Jacket',
#  'Columbia Men s Trail Turner Shell Jacket',
#  'Russell Mens 3 Layer Soft Shell Gilet Jacket',
#  'Columbia Men s Coupe De Main Jacket',
#  'Columbia Men s Omni Heat Insulated liner',
#  'Port Authority Challenger Jacket 4XL true Royal True Navy',
#  'Columbia Men s Heat 360 Jacket Small Black',
#  'Columbia Men s Ice Axe III Softshell',
#  'Columbia Men s Horicon Marsh Jacket',
#  'Port Authority Men s tall Textured Soft Shell Jacket',
#  'Spyder Men s Shadow Insulator Jacket',
#  'Port Authority 3 1 Jacket Black Black',
#  'Mountain Warehouse Torrent Mens Waterproof Jacket',
#  'Manfrotto MA LSS050 M XLBB Men s PRO Soft Shell Jacket XL Black',
#  'Columbia Men s Omni Heat Wader Widgeon Parka',
#  'IKIIO Mens Fleece Sherpa Lined Jacket Hooded Sweatshirt Zip Winter Warm Coat',
#  'ATG Wrangler Men s Reversible Classic Jacket',
#  'Columbia Men s Carabineer II Parka',
#  'Armour Men s Trail Run Hybrid 1 2 Zip jacket',
#  'Columbia Men s Greene Trail Jacket',
#  'Port Authority hood Soft Shell Jacket J335 Black Battleship Grey 4xl',
#  'Columbia Men s Jet Stratus Shell Jacket Medium Black',
#  'Columbia Men s Marlin Rig Hoody',
#  'Jack Wolfskin Men s Northern Point JKT M',
#  'Jack Wolfskin Men s Brockton Pt Jacket Black Medium',
#  'Port Authority Men s Tall Competitor Jacket',
#  'Columbia Sportswear Men s Smooth Pursuit Softshell Extended Jacket Big',
#  'Columbia Sportswear Men s Smooth Pursuit Softshell Tall Jacket',
#  'Columbia Sportswear Men s Cubist IV Jacket',
#  'Radians SJ510 Quilted reversible 4 1 Jacket Zip Sleeves Medium',
#  'Salomon ICEFROST JACKET men',
#  'LONDON FOG Men s Waterproof Breathable Seam Sealed Rip Stop Hooded Shell Jacket',
#  'Columbia Men s Access Point Shell',
#  'Rocawear Men s Outerwear Jacket',
#  'Columbia Men s Triteca Softshell Jacket Black Medium',
#  'Jack Wolfskin men Scandic Jacket Men',
#  'Hydro Parka',
#  'Pearl Izumi Run Men s Fly Jacket',
#  'Salomon Women s Sashay Men s jacket',
#  'Columbia Men s Baseplate Jacket',
#  'Columbia Men s Stealth Shot II Jacket',
#  'Mens MA 1 Flight Bomber Jacket Active Casual Military Outwear',
#  'Oakley Men s Velocity Storm Shell',
#  'Volcom Men s Stripester Medium Weight hood Puff Jacket',
#  'cutter Buck Men s Cb Weathertec Beacon V Neck Jacket',
#  'Mizuno Running Men s Breath Thermo Jacket',
#  'ArcticShield Arctic Shield Mens Classic Waterfowl Parka',
#  'Columbia Men s Sawyers Creek Softshell',
#  'Element Men s Alder',
#  'Columbia Men s Rain scape Jacket',
#  'Salomon Men s Nova Soft Shell Jacket',
#  'Columbia Men s Trail Fire Windbreaker Jacket Small Black',
#  'Columbia Men s Key II Softshell Jacket Buffalo X large',
#  'Columbia Men s Tamiami Hurricane Jacket',
#  'helly Hansen Men s Tofino Cis Jacket',
#  'Fjällräven Expedition Pack Hoodie',
#  'DC Men s Command Insulator Packable Jacket',
#  'Dunbrooke Men s Yukon Jacket',
#  'Columbia Men s Backpaddle II Jacket Shell top',
#  'icebreaker Merino Men s Blast Jacket Merino Wool',
#  'Mountain Hardwear Men s Mt Eyak hoody',
#  'Armour Men s Grit Jacket',
#  'Columbia Men s Triple Trail Shell',
#  'ICEWEAR Njáll 3 Layer Hard Shell Jacket',
#  'Holloway Potomac Jacket Xl Royal White',
#  'Spyder Men s gear Hoody Synthetic Jacket',
#  'Woolrich Men s Absolute Insulated Softshell Jacket',
#  'Columbia Men s Omni Heat Squall Line Insulated Fishing Liner',
#  'Salomon Men s Charvin Softshell Jacket',
#  'Gore Bike Wear Men s Contest 2 0 active Shell Jacket Red Black White Small',
#  'Columbia Men s Landlash Softshell',
#  'Columbia Men s Triteca Softshell Jacket Black X large',
#  'Columbia Sportswear Men s Fusion Exact Jacket',
#  'STS Ranchwear Men s Brazos Softshell Barn jacket',
#  'Columbia Sportswear Men s Powerfly Puff Jacket',
#  'Columbia Men s Path Ii jacket',
#  'helly Hansen Men s Verglas Lightweight Waterprooof Windproof Breathable hood 3 Layer Shell Jacket',
#  'Jack Wolfskin Men s Cloudburst jacket',
#  'Armour Men s Ridge Reaper Gore Pro Shell Jacket',
#  'helly Hansen 62774 Men s Verglas insulator',
#  'neff Men s World Champ Jacket',
#  'Columbia Men s Tree Grinder Shell Jacket',
#  'ASICS Logo Fleece jacket',
#  'helly Hansen Men s Belfast 2 packable jacket',
#  'Port Authority Men s Brushstroke Print Insulated Jacket',
#  'HFX Men s poly Hooded Puffer Breast pocket',
#  'Columbia Sportswear Men s Hooded jacket',
#  'ASICS Men s Lite Winter Jacket',
#  'Columbia Men s Tectonic Access Softshell Jacket Medium Black',
#  'Columbia Men s Modern Logger Jacket',
#  'helly Hansen Mens LIFALOFT Insulator Pullover',
#  'Columbia Men s Assimilate Softshell Jacket',
#  'Columbia Men s Omni Heat wading Jacket Small Black',
#  'Ash City Core 365 Men s Techno Lite Layer Knit Tech Shell 2xl BLACK',
#  'ATG Wrangler Men s Range Jacket',
#  'Armour Men s ColdGear Reactor Hybrid Lite Jacket',
#  'Columbia Men s Peak II Shell Jacket Small Black',
#  'Columbia Men s Compounder Shell Jacket',
#  'Columbia Men s Cubique II Jacket',
#  'Helikon Gunfighter Soft Shell Jacket Coyote',
#  'Columbia Sportswear Men s Zephyr Ridge Jacket Deep Woods XX large',
#  'DuDubaby Mens Zip Jacket Zip Jacket Mens Slim Lapel Cardigan Coat Jacket Light heat Outwear Windproof Jacket Men',
#  'Columbia Men s Omni Heat match play jacket',
#  'Vertx Recon Shell Jacket Multi Cam xx Large Regular',
#  'Columbia Men s Hot Shot II Shell',
#  'Fjallraven Keb Jacket Men s',
#  'Armour Outerwear Men s Scrambler Hybrid Jacket',
#  'Yoko Men s hi Vis Sofshell Jacket',
#  'Craft Men s Primaloft Stow Light Jacket Packable Primaloft Quilted Jacket',
#  'Oakley Men s Tc Gunn Shell 2l jacket',
#  'Columbia Men s Triteca Softshell Jacket Black Small',
#  'Jack Wolfskin Men s Jwp Hybrid Insulated Jacket',
#  'Oakley DWR Elkhorn Jacket',
#  'Columbia Men s Heatstream Softshell',
#  'D Jones Men s hood Soft Shell Jacket',
#  'Mountain Warehouse Glacier II Mens Long Waterproof Jacket',
#  'ScentBlocker Matrix Men s Jacket Windbrake',
#  'Columbia Men s Trophy Shot Jacket',
#  'Columbia Men s Triteca Softshell Jacket Sanguine X large',
#  'arc teryx Atom Hoody Men s Lightweight Versatile Synthetically insulate Hoody',
#  'Bikers Zone Heated Soft Shell Jacket 12v Battery 4 x Heating zone padding',
#  'Columbia Men s PHG Long insulate Liner Jacket',
#  'Dickies Men s Performance Premium Softshell Jacket',
#  'Fjallraven Skog Shirt Men s',
#  'Jack Wolfskin Men s Atlas Tour JKT M',
#  'Fjallraven Men s Keb Jacket',
#  'Salomon Men s Zero Jacket',
#  'Greg Norman Collection Men s Luxury Cotton V Neck Sweater',
#  'Columbia Sportswear Men s Hells Mountain Interchange Jacket',
#  'Columbia Sportswear Shimmer Timbers II Omni Heat Insulated Jacket Men s',
#  'Columbia Men s Brass II jacket',
#  'Columbia Sportswear Men s Key II Softshell Jacket',
#  'Jack Wolfskin Helium Men',
#  'Columbia Men s Heat Elite Jacket',
#  'craghopper Men s Track Soft Shell Jacket',
#  'Salomon Men s Halo Jacket',
#  'helly Hansen Men s active Insulated Fall Jacket',
#  'Spyder Men s Raider Zip Sweater Pick color',
#  'Columbia Sportswear Men s Zephyr Ridge Jacket',
#  'Columbia Men s Summit Rush Zip jacket',
#  'Columbia Sportswear Men s Evergreen Shell Jacket',
#  'Columbia Sportswear Men s Mighty Light Jacket',
#  'Red Ledge Men s Free Rein parka',
#  'Dominator Waterproof Jacket TT86',
#  'Columbia Sportswear Men s Evaporation Jacket',
#  'O2 Rainwear Men s Element Series Hooded Jacket',
#  'Vince Camuto Men s Carbon Coated Quilted Jacket',
#  'helly Hansen Mens Urban Long Waterproof Jacket',
#  'helly Hansen 53145 Men s Chill Parka',
#  'Columbia Men s CLG Sideline Parka',
#  'Columbia Men s Grade Max Softshell Jacket',
#  'Oakley Men s Crescent 3 0 Shell Jacket',
#  'Port Authority Tall Lightweight Charger Jacket TLJ329',
#  'DRI Duck Men s Outlaw Jacket',
#  'Port Authority 1 2zip Wind Jacket J703',
#  'Peregrine Wild Hare Cold Weather Insulated Coat Black Leather Right Hand X large wh 480l BK RH XL',
#  'Striker Boys Climate Durable Windproof Water Resistant Insulated Outdoor Ice Fishing Jacket Removable Hood',
#  'Salomon Men s Insulated Hoodie Jacket',
#  'Salomon Men s insulated Jacket',
#  'Gore Men s r5 Gws Jacket',
#  'Ashe City Men s Techno Lite Layer Knit Tech Shell',
#  'Columbia Sportswear Men s Grade Max Hooded Jacket',
#  'Jordan Craig Men block Puffer Jacket Burgundy',
#  'helly Hansen Mens Power Air Heat Grid Fleece Insulator Jacket',
#  'ARENA Official USA Swimming National Team Unisex Zip Hooded jacket',
#  'Mountain Hardwear Men s Stratus Range Zip',
#  'HFX Men s Puffer Jacket Hood Water Wind Resistant',
#  'Salomon Men s Agile Half Zip Mid',
#  'Ash City North end Adult 3 1 Parka Dobby Trim 2xl MIDNIGHT NAVY',
#  'Armour Men s Storm ColdGear infrared windstopper Shadow Jacket',
#  'Salomon Men s Brilliant Jacket',
#  'Columbia Men s Tectonic Softshell',
#  'Castelli Men s Jacket Windproof Water Resistant Breathable Protective Shell Road Gravel Biking Cycling',
#  'MFH Men s Security Jacket Black',
#  'Reebok Men s Multi Puffer',
#  'Backpacker Zip Canvas Jacket',
#  'Port Authority Competitor Jacket',
#  'Wildfowler Men s Contoured fit',
#  'Columbia Men s Thermodynamic Softshell',
#  'Columbia Men s Lush Plush Jacket',
#  '100 polyester',
#  'hazard 4 Action Agent TM Softshell Urban Jacket r',
#  'Columbia Sportswear Men s Smooth Pursuit Softshell Jacket',
#  'helly Hansen Men s Mono Material Hooded Insulator',
#  'Nexgen Heat Men s Standard Mpm111762set Grey Zipper Soft Shell Jacket',
#  'Columbia Sportswear Men s Horizons Pine Interchange Tall Jacket',
#  'Columbia Men s Tipton Peak Insulated Omni Heat Waterproof hood jacket',
#  'Armour Men s coldgearâ Reactor Hybrid ½ Zip',
#  'Clique Men s Crystal Mountain Jacket']
