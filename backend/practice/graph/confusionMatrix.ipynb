# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics
import json
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import scipy.sparse as sp

with open('C:/Hammad Aslam/BS IT (post ADP)/3rd Semester/Capstone Project/Project/backend/datasets/categories/allFiles/computers_laptops.json', 'r') as f:
    data = json.load(f)
review_texts = [data[0]['reviews'][1]['review_topics'][0]]
sentiment = [data[0]['reviews'][1]['sentiment']]
# vectorizer = TfidfVectorizer(max_features=1000)  # Set a maximum number of features (optional)
vectorizer = CountVectorizer()
actual = vectorizer.fit_transform(review_texts)
if isinstance(actual, sp.csr.csr_matrix):
  dense_reviews = actual.toarray()
  print(dense_reviews.shape)
predicted = vectorizer.fit_transform(sentiment)
if isinstance(predicted, sp.csr.csr_matrix):
  dense_senti = actual.toarray()
  print(dense_senti.shape)
actual = numpy.random.binomial(1,.9,size = 10)
print(dense_reviews)
predicted = numpy.random.binomial(1,.9,size = 10)

confusion_matrix = metrics.confusion_matrix(actual, predicted)
Accuracy = metrics.accuracy_score(actual, predicted)
print(Accuracy)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [0, 1])

cm_display.plot()
plt.show()
# Out:
# C:\Users\GS\AppData\Local\Temp\ipykernel_11512\527954491.py:15: DeprecationWarning: Please use `csr_matrix` from the `scipy.sparse` namespace, the `scipy.sparse.csr` namespace is deprecated.
#   if isinstance(actual, sp.csr.csr_matrix):
# C:\Users\GS\AppData\Local\Temp\ipykernel_11512\527954491.py:19: DeprecationWarning: Please use `csr_matrix` from the `scipy.sparse` namespace, the `scipy.sparse.csr` namespace is deprecated.
#   if isinstance(predicted, sp.csr.csr_matrix):
# (1, 2)
# (1, 2)
# [[1 1]]
# 0.8
